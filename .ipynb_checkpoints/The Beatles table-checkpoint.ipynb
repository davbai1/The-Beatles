# %%
import pandas as pd

df = pd.read_csv('The Beatles songs dataset 285x45 v0.csv')
to_drop = ['URI', 'Time_signature', 'Energy', 'Loudness', 'Instrumentalness', 'Speechiness', 'Tempo', 'Other releases', 'Single A side', 'Single B side', 'Single certification', 'Styles', 'Themes', 'Moods', 'Songwriter(s)', 'Lead vocal(s)', 'Cover', 'Covered by', 'Chart position UK (Wikipedia)', 'Chart position US (Wikipedia)', 'Highest position (The Guardian)', 'Weeks on chart in UK (The Guardian)', 'Weeks at No1 in UK (The Guardian)', 'Highest position (Billboard)', 'Weeks at No1 (Billboard)', 'Top 50 (Billboard)', 'Top 50 (Ultimate classic rock)', 'Top 50 (NME)', 'Top 50 (Top50songs.org)', 'Album', 'Genre', 'Top 50 (USA today, 2017)','Album debut', 'Top 50 (Vulture, by Bill Wyman)']

df.drop(to_drop, inplace = True, axis = 1)
df.head(10)
# Out:
#                                                Title  Year  Popularity  \
# 0  (You're So Square) Baby I Don't Care - Studio Jam   NaN        29.0
# 1                                    12-bar Original  1965        31.0
# 2                  A Beginning - Anthology 3 Version   NaN        29.0
# 3                                  A Day in the Life  1967        65.0
# 4                                 A Hard Day's Night  1964        71.0
# 5                         A Shot of Rhythm and Blues  1963        35.0
# 6                                   A Taste of Honey  1963        51.0
# 7                                Across the Universe  1968        69.0
# 8  Across the Universe - Take 2 / Anthology 2 Ver...   NaN        35.0
# 9                                      Act Naturally  1965        52.0
#
#    Duration  Key  Mode  Valence  Danceability  Acousticness  Liveness  \
# 0      43.0  9.0   1.0    0.353         0.411       0.09910    0.3640
# ...

# %%
df.describe()
# Out:
#        Popularity    Duration         Key        Mode     Valence  \
# count  285.000000  285.000000  285.000000  285.000000  285.000000
# mean    50.087719  158.407018    4.961404    0.856140    0.692141
# std     14.415466   57.361001    3.387308    0.351565    0.234652
# min     22.000000   23.000000    0.000000    0.000000    0.033000
# 25%     39.000000  128.000000    2.000000    1.000000    0.553000
# 50%     52.000000  149.000000    4.000000    1.000000    0.735000
# 75%     59.000000  175.000000    9.000000    1.000000    0.886000
# max     87.000000  502.000000   11.000000    1.000000    0.979000
#
#        Danceability  Acousticness    Liveness  Top 50 (Rolling Stone)
# count    285.000000    285.000000  285.000000               49.000000
# mean       0.528540      0.385921    0.226137               25.551020
# std        0.131461      0.287988    0.196666               14.723933
# min        0.146000      0.000028    0.037100                1.000000
# ...

# %%
#Replace NaN in columns Year and Top 50(Rolling Stones)
df['Year'].fillna(df['Year'].median(), inplace = True)
